# %%
! aws s3 ls dev-et-data/NA_data_for_cloud/
# Out:
#                            PRE ETo_mosaic/
#                            PRE NDVI/
#                            PRE NDVI2/
#                            PRE Precipitation_withHawaiiPuertoRico/
#                            PRE Soil/
#                            PRE Temperature/
# 2020-05-22 17:33:48  364931586 global_water_mask_inland.tif

# %%
! aws s3 ls dev-et-data/NA_data_for_cloud/Precipitation_withHawaiiPuertoRico/
# Out:
#                            PRE 2001/
#                            PRE 2002/
#                            PRE 2003/
#                            PRE 2004/
#                            PRE 2005/
#                            PRE 2006/
#                            PRE 2007/
#                            PRE 2008/
#                            PRE 2009/
#                            PRE 2010/
#                            PRE 2011/
#                            PRE 2012/
#                            PRE 2013/
#                            PRE 2014/
#                            PRE 2015/
#                            PRE 2016/

# %%
! aws s3 ls dev-et-data/NA_data_for_cloud/ETo_mosaic/
# Out:
# 2020-05-22 14:58:47         83 pet001.tfw
# 2020-05-22 14:58:47 2815130906 pet001.tif
# 2020-05-22 14:58:47       2734 pet001.tif.aux.xml
# 2020-05-22 14:58:47  599911358 pet001.tif.ovr
# 2020-05-22 14:58:47         83 pet002.tfw
# 2020-05-22 14:58:47 2814442690 pet002.tif
# 2020-05-22 14:58:47       2732 pet002.tif.aux.xml
# 2020-05-22 14:58:47         83 pet003.tfw
# 2020-05-22 14:58:47 2814442690 pet003.tif
# 2020-05-22 14:58:47       2728 pet003.tif.aux.xml
# 2020-05-22 14:58:48         83 pet004.tfw
# 2020-05-22 14:58:49 2814442690 pet004.tif
# 2020-05-22 14:59:01       2725 pet004.tif.aux.xml
# 2020-05-22 14:59:01         83 pet005.tfw
# 2020-05-22 14:59:01 2814442690 pet005.tif
# 2020-05-22 15:00:01       2718 pet005.tif.aux.xml
# 2020-05-22 15:00:01         83 pet006.tfw
# 2020-05-22 15:00:01 2814442690 pet006.tif
# 2020-05-22 15:00:05       2719 pet006.tif.aux.xml
# 2020-05-22 15:00:05         83 pet007.tfw
# 2020-05-22 15:00:05 2814442690 pet007.tif
# ...

# %%
! aws s3 cp s3://dev-et-data/NA_data_for_cloud/ETo_mosaic/pet365.tif s3://dev-et-data/NA_data_for_cloud/ETo_mosaic/pet366.tif
# Out:
# copy: s3://dev-et-data/NA_data_for_cloud/ETo_mosaic/pet365.tif to s3://dev-et-data/NA_data_for_cloud/ETo_mosaic/pet366.tif

# %%
! aws s3 ls dev-et-data/NA_data_for_cloud/ETo_mosaic/ | tail
# Out:
# 2020-05-22 16:38:42         83 pet363.tfw
# 2020-05-22 16:38:42 2814442690 pet363.tif
# 2020-05-22 16:38:46       2734 pet363.tif.aux.xml
# 2020-05-22 16:38:46         83 pet364.tfw
# 2020-05-22 16:38:47 2814442690 pet364.tif
# 2020-05-22 16:39:09       2733 pet364.tif.aux.xml
# 2020-05-22 16:39:09         83 pet365.tfw
# 2020-05-22 16:39:10 2814442690 pet365.tif
# 2020-05-22 16:39:50       2729 pet365.tif.aux.xml
# 2020-06-22 14:31:37 2814442690 pet366.tif

# %%
! aws s3 ls dev-et-data/NA_data_for_cloud/NDVI2/
# Out:
#                            PRE 2001/
#                            PRE 2002/
#                            PRE 2003/
#                            PRE 2004/
#                            PRE 2005/
#                            PRE 2006/
#                            PRE 2007/
#                            PRE 2008/
#                            PRE 2009/
#                            PRE 2010/
#                            PRE 2011/
#                            PRE 2012/
#                            PRE 2013/
#                            PRE 2014/
#                            PRE 2015/
#                            PRE 2016/

# %%
! aws s3 ls dev-et-data/NDVI_filled/med2003_2017/
# Out:
# 2020-04-26 14:28:55         83 med001.250_m_NDVI.tfw
# 2020-04-26 14:28:55 2882174998 med001.250_m_NDVI.tif
# 2020-04-26 14:28:55       2160 med001.250_m_NDVI.tif.aux.xml
# 2020-04-26 14:28:55         83 med002.250_m_NDVI.tfw
# 2020-04-26 14:28:56 2882174996 med002.250_m_NDVI.tif
# 2020-04-26 14:28:56       2156 med002.250_m_NDVI.tif.aux.xml
# 2020-04-26 14:28:56         83 med003.250_m_NDVI.tfw
# 2020-04-26 14:28:56 2882174996 med003.250_m_NDVI.tif
# 2020-04-26 14:28:56       2156 med003.250_m_NDVI.tif.aux.xml
# 2020-04-26 14:28:56         83 med004.250_m_NDVI.tfw
# 2020-04-26 14:28:56 2882174998 med004.250_m_NDVI.tif
# 2020-04-26 14:28:56       2158 med004.250_m_NDVI.tif.aux.xml
# 2020-04-26 14:28:56         83 med005.250_m_NDVI.tfw
# 2020-04-26 14:28:56 2882174998 med005.250_m_NDVI.tif
# 2020-04-26 14:30:25       2161 med005.250_m_NDVI.tif.aux.xml
# 2020-04-26 14:30:25         83 med006.250_m_NDVI.tfw
# 2020-04-26 14:30:26 2882174998 med006.250_m_NDVI.tif
# ...

# %% [markdown]
# # Today
#
# 1. ran delaware locally on windows
# 2. 20 years - of delaware -
#     - brag about in the cloud
#     - outputs ? - lots of data - pull
#     - daily monthly and yearly
#     - ward sanford - shapefile
#     - 20 years * 3.5 hours per year
#     - bug == no pet366 day - data - so it bombs
#     - iterim steps - today? - run 3 or 5 years

# %%
! ls ; pwd
# Out:
# 00-analyze-logs-timings-delaware.ipynb	Readme.md	 sample_config
# Dockerfile				delaware_config
# Makefile				log.log
# /home/jupyter-kagone/train/etops/veget_c

# %%
! cat Makefile
# Out:
# Image=tbutzer/veget_c
#
# build:
# 	docker build -t ${Image} .
#
# run:
# 	docker run -it ${Image} bash
#
# exec:
# 	docker exec -it ${Image} bash
#
# git:
# 	(cd /opt/etops ; make)
#
#
# dela_logs:
# 	docker run -i ${Image} python3 api_veget.py -c delaware_config -s DRB.shp lilDRB_temp

# %% [markdown]
# # Running in Docker Notes
#
# ```
# tmux
#
# make dela_logs 2>&1 | tee log.log
#
# ```
#
#
# ### make dela_logs 2>&1 | tee log.log

# %%
! head log.log
# Out:
# docker run -i tbutzer/veget_c python3 api_veget.py -c delaware_config -s DRB.shp lilDRB_temp
# 2020-06-20 15:41:43,742 - BOXY_THINGYS - INFO - Logging Begins
# 2020-06-20 15:41:43,743 - CLOUD_VEGET - INFO - Logging Begins
# 2020-06-20 15:41:43,744 - CLOUD_VEGET - INFO - Processing Tile lilDRB_temp
# 2020-06-20 15:41:43,744 - CLOUD_VEGET - ERROR - Someday tony needs to refine logging and determine a std format for ELK
# 2020-06-20 15:41:43,745 - CLOUD_VEGET - ERROR - or logging agents and logging backends ... docker deployments
# 2020-06-20 15:41:43,745 - VegET_CLASS - INFO - Logging Begins
# 2020-06-20 15:41:43,745 - VegET_CLASS - INFO - TILE is lilDRB_temp
# 2020-06-20 15:41:43,745 - VegET_CLASS - INFO - Important Config path is delaware_config
# 2020-06-20 15:41:43,760 - VegET_CLASS - INFO - Important path mode is aws

# %%
def read_log(filename):
    with open(filename) as f:
        content = f.read().splitlines()
    return content

# %%
lines = read_log('log.log')

# %%
for i in range(0,12):
    print(lines[i])
# Out:
# docker run -i tbutzer/veget_c python3 api_veget.py -c delaware_config -s DRB.shp lilDRB_temp
# 2020-06-20 15:41:43,742 - BOXY_THINGYS - INFO - Logging Begins
# 2020-06-20 15:41:43,743 - CLOUD_VEGET - INFO - Logging Begins
# 2020-06-20 15:41:43,744 - CLOUD_VEGET - INFO - Processing Tile lilDRB_temp
# 2020-06-20 15:41:43,744 - CLOUD_VEGET - ERROR - Someday tony needs to refine logging and determine a std format for ELK
# 2020-06-20 15:41:43,745 - CLOUD_VEGET - ERROR - or logging agents and logging backends ... docker deployments
# 2020-06-20 15:41:43,745 - VegET_CLASS - INFO - Logging Begins
# 2020-06-20 15:41:43,745 - VegET_CLASS - INFO - TILE is lilDRB_temp
# 2020-06-20 15:41:43,745 - VegET_CLASS - INFO - Important Config path is delaware_config
# 2020-06-20 15:41:43,760 - VegET_CLASS - INFO - Important path mode is aws
# 2020-06-20 15:41:43,761 - COOL RASTERMANAGER - INFO - Logging Begins
# ...

# %%
for i in range(0,len(lines)):
    if ('VegET_CLASS ' in lines[i]) and ('DAY' in lines[i]):
        print(lines[i])
# Out:
# 2020-06-20 15:42:28,666 - VegET_CLASS - INFO - DAY - TIME - 23.82932587713003 - 2012-11-30 00:00:00
# 2020-06-20 15:44:34,163 - VegET_CLASS - INFO - DAY - TIME - 125.49668184807524 - 2012-12-01 00:00:00
# 2020-06-20 15:45:14,139 - VegET_CLASS - INFO - DAY - TIME - 39.975049721077085 - 2012-12-02 00:00:00
# 2020-06-20 15:45:41,057 - VegET_CLASS - INFO - DAY - TIME - 26.918258279096335 - 2012-12-03 00:00:00
# 2020-06-20 15:46:08,599 - VegET_CLASS - INFO - DAY - TIME - 27.541604122146964 - 2012-12-04 00:00:00
# 2020-06-20 15:46:35,934 - VegET_CLASS - INFO - DAY - TIME - 27.33454190334305 - 2012-12-05 00:00:00
# 2020-06-20 15:46:59,719 - VegET_CLASS - INFO - DAY - TIME - 23.78530544321984 - 2012-12-06 00:00:00
# 2020-06-20 15:47:31,415 - VegET_CLASS - INFO - DAY - TIME - 31.69551506312564 - 2012-12-07 00:00:00
# 2020-06-20 15:48:00,269 - VegET_CLASS - INFO - DAY - TIME - 28.853522011078894 - 2012-12-08 00:00:00
# ...

# %%
import pandas as pd
df = pd.DataFrame(columns=["day", "time"])
for i in range(0,len(lines)):
    if ('VegET_CLASS ' in lines[i]) and ('DAY' in lines[i]):
        print(lines[i])
        _items = lines[i].split(' - ')
        print(_items[5], _items[6])
        df = df.append({"day": _items[6],"time": _items[5]}, ignore_index=True)
# Out:
# 2020-06-20 15:42:28,666 - VegET_CLASS - INFO - DAY - TIME - 23.82932587713003 - 2012-11-30 00:00:00
# 23.82932587713003 2012-11-30 00:00:00
# 2020-06-20 15:44:34,163 - VegET_CLASS - INFO - DAY - TIME - 125.49668184807524 - 2012-12-01 00:00:00
# 125.49668184807524 2012-12-01 00:00:00
# 2020-06-20 15:45:14,139 - VegET_CLASS - INFO - DAY - TIME - 39.975049721077085 - 2012-12-02 00:00:00
# 39.975049721077085 2012-12-02 00:00:00
# 2020-06-20 15:45:41,057 - VegET_CLASS - INFO - DAY - TIME - 26.918258279096335 - 2012-12-03 00:00:00
# 26.918258279096335 2012-12-03 00:00:00
# 2020-06-20 15:46:08,599 - VegET_CLASS - INFO - DAY - TIME - 27.541604122146964 - 2012-12-04 00:00:00
# 27.541604122146964 2012-12-04 00:00:00
# 2020-06-20 15:46:35,934 - VegET_CLASS - INFO - DAY - TIME - 27.33454190334305 - 2012-12-05 00:00:00
# 27.33454190334305 2012-12-05 00:00:00
# 2020-06-20 15:46:59,719 - VegET_CLASS - INFO - DAY - TIME - 23.78530544321984 - 2012-12-06 00:00:00
# ...

# %%
df
# Out:
#                     day                time
# 0   2012-11-30 00:00:00   23.82932587713003
# 1   2012-12-01 00:00:00  125.49668184807524
# 2   2012-12-02 00:00:00  39.975049721077085
# 3   2012-12-03 00:00:00  26.918258279096335
# 4   2012-12-04 00:00:00  27.541604122146964
# 5   2012-12-05 00:00:00   27.33454190334305
# 6   2012-12-06 00:00:00   23.78530544321984
# 7   2012-12-07 00:00:00   31.69551506312564
# 8   2012-12-08 00:00:00  28.853522011078894
# 9   2012-12-09 00:00:00   24.94494657823816
# 10  2012-12-10 00:00:00  23.247636005748063
# 11  2012-12-11 00:00:00  128.42130952281877
# 12  2012-12-12 00:00:00  26.023649082984775
# 13  2012-12-13 00:00:00    29.7276747841388
# 14  2012-12-14 00:00:00  24.062160547822714
# 15  2012-12-15 00:00:00   32.56388711696491
# 16  2012-12-16 00:00:00  27.879244490992278
# 17  2012-12-17 00:00:00  28.045485159382224
# 18  2012-12-18 00:00:00  28.061447184998542
# 19  2012-12-19 00:00:00  25.466194191016257
# ...

# %%
df.dtypes
# Out:
# day     object
# time    object
# dtype: object

# %%
df.time = df.time.astype(float)
df.dtypes
# Out:
# day      object
# time    float64
# dtype: object

# %%
df.describe()
# Out:
#              time
# count   26.000000
# mean    35.601138
# std     27.281398
# min     23.019805
# 25%     25.248078
# 50%     27.438073
# 75%     29.556936
# max    128.421310

# %%
df.agg({'time': ['min', 'max', 'median', 'skew']})
# Out:
#               time
# min      23.019805
# max     128.421310
# median   27.438073
# skew      3.218107

# %%
df['time'].min()
# Out:
# 23.019805199932307

# %%
df['time'].mean()
# Out:
# 35.601138437650384

# %%
one_day = 36 #seconds

one_year = 366 * one_day # seconds

one_year
# Out:
# 13176

# %%
time_for_one_year_in_hours = one_year / 60 / 60

# %%
time_for_one_year_in_hours
# Out:
# 3.6599999999999997

# %%
df.plot()

# %%
data_shape = (3116, 1940)

# %%
num_pixels = data_shape[0] * data_shape[1]

# %%
num_pixels
# Out:
# 6045040

# %%
seconds_per_pixel = df['time'].mean() / num_pixels

# %%
seconds_per_pixel
# Out:
# 5.889313956177359e-06
